# %%
import pandas as pd
import numpy as np
import random

# %%
data = pd.read_excel('../data/model_data.xlsx')
df = data.copy()
df.head()
# Out:
#   ilce_adi mahalle_adi tarimsal_sulama_suyu sulama_suyu_kaynagi_yonetimi  \
# 0   Ahırlı    ALİÇERÇİ                  YOK                          YOK
# 1   Ahırlı     BADEMLİ                  YOK                          YOK
# 2   Ahırlı   BALIKLAVA                  VAR               SULAMA BİRLİĞİ
# 3   Ahırlı     BÜYÜKÖZ                  VAR                ŞAHSİ KUYULAR
# 4   Ahırlı     ÇİFTLİK                  VAR                ŞAHSİ KUYULAR
#
#               en_cok_yetistirilen_urunler  \
# 0  BUĞDAY, ARPA, MERCİMEK, NOHUT, FASULYE
# 1               BUĞDAY, ARPA, NOHUT, ERİK
# 2              BUĞDAY, ELMA, ÇİLEK, NOHUT
# 3                            BUĞDAY, ARPA
# 4                   BUĞDAY, ARPA, FASULYE
#
#   sulanabilir_alanda_yetistirilen_urunler  \
# 0                                     YOK
# 1                                     YOK
# 2         ELMA, KİRAZ, VİŞNE, ÇİLEK, ERİK
# 3                            BUĞDAY, ARPA
# 4                                 FASULYE
#
# ...

# %%
ilceler_yagis = {
    'Ahırlı': 550,
    'Akören': 300,
    'Akşehir': 499,
    'Altınekin': 375,
    'Beyşehir': 580,
    'Bozkır': 580,
    'Cihanbeyli': 290,
    'Çeltik': 397,
    'Çumra': 306,
    'Derbent': 530,
    'Derebucak': 500,
    'Doğanhisar': 600,
    'Emirgazi': 250,
    'Ereğli': 277,
    'Güneysınır': 310,
    'Hadim': 690,
    'Halkapınar': 375,
    'Hüyük': 580,
    'Ilgın': 340,
    'Kadınhanı': 380,
    'Karapınar': 279,
    'Karatay': 320,
    'Kulu': 275,
    'Meram': 400,
    'Sarayönü': 300,
    'Selçuklu': 318,
    'Seydişehir': 679,
    'Taşkent': 550,
    'Tuzlukçu': 375,
    'Yalıhüyük': 920,
    'Yunak': 225
}

df_ilceler_yagis = pd.DataFrame(list(ilceler_yagis.items()), columns=['ilce_adi', 'yagis_miktari (mm)'])

print(type(df_ilceler_yagis))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df['yagis_miktari (mm)'] = df['ilce_adi'].map(ilceler_yagis)
df[0:500:30]
# Out:
#        ilce_adi mahalle_adi tarimsal_sulama_suyu  \
# 0        Ahırlı    ALİÇERÇİ                  YOK
# 30      Akşehir       ÇAMLI                  VAR
# 60    Altınekin   HACINUMAN                  VAR
# 90     Beyşehir     EĞİRLER                  VAR
# 120    Beyşehir    YEŞİLDAĞ                  VAR
# 150      Bozkır       KINIK                  VAR
# 180      Çeltik  İSHAKUŞAĞI                  VAR
# 210  Cihanbeyli    TAŞPINAR                  VAR
# 240       Çumra   DİNLENDİK                  VAR
# 270   Derebucak      GENCEK                  VAR
# 300    Emirgazi     ÖBEKTAŞ                  YOK
# 330      Ereğli   KUSKUNCUK                  VAR
# 360  Güneysınır     KIZILÖZ                  VAR
# 390       Hadim      YELMEZ                  VAR
# 420       Hüyük        KÖŞK                  VAR
# 450       Ilgın    GÖKBUDAK                  VAR
# 480   Kadınhanı    ÇEŞMECİK                  YOK
#
#           sulama_suyu_kaynagi_yonetimi  \
# ...

# %%
def update_sulak_alan(row):
    yeni_sulak_alan_miktari = random.randint(10, 30)  
    return str(yeni_sulak_alan_miktari) + '%';

df['sulak_alan_miktari'] = df.apply(update_sulak_alan, axis=1)
df[df['ilce_adi'] == 'Karapınar']
# Out:
#       ilce_adi  mahalle_adi tarimsal_sulama_suyu  \
# 511  Karapınar      HOTAMIŞ                  VAR
# 512  Karapınar       KESMEZ                  VAR
# 513  Karapınar     AKÇAYAZI                  VAR
# 514  Karapınar       AKÖREN                  VAR
# 515  Karapınar        ÇİĞİL                  VAR
# 516  Karapınar     HASANOBA                  VAR
# 517  Karapınar        İSLİK                  VAR
# 518  Karapınar    KARAKIŞLA                  VAR
# 519  Karapınar      KAYACIK                  VAR
# 520  Karapınar       KAYALI                  VAR
# 521  Karapınar  KAZANHÜYÜĞÜ                  VAR
# 522  Karapınar  KÜÇÜKAŞLAMA                  VAR
# 523  Karapınar      ORTAOBA                  VAR
# 524  Karapınar       OYMALI                  VAR
# 525  Karapınar   SAZLIPINAR                  VAR
# 526  Karapınar   YAĞMAPINAR                  VAR
# 527  Karapınar     YENİKUYU                  VAR
# 528  Karapınar    YEŞİLYURT                  VAR
#
# ...

# %%
categories = {
    'Verimli Toprak, Yüksek Su İhtiyacı': 'A',
    'Verimli Toprak, Orta Su İhtiyacı': 'B',
    'Killi Toprak, Yüksek Su İhtiyacı': 'C',
    'Killi Toprak, Orta Su İhtiyacı': 'D',
    'Killi Toprak, Düşük Su İhtiyacı': 'E',
    'Kumlu Toprak, Yüksek Su İhtiyacı': 'F',
    'Kumlu Toprak, Düşük Su İhtiyacı': 'G',
}

def determine_category(row):
    toprak = row['toprak_tipi']
    sulak = int(row['sulak_alan_miktari'].replace('%', '')) 
    
    if 'Verimli' in toprak and sulak > 65:
        return 'A'
    elif 'Verimli' in toprak and 25 <= sulak <= 65:
        return 'B'
    elif 'Verimli' in toprak and sulak < 25:
        return 'G'
    elif 'Killi' in toprak and sulak > 65:
        return 'A'
    elif 'Killi' in toprak and 25 <= sulak <= 65:
        return 'C'
    elif 'Killi' in toprak and sulak < 25:
        return 'G'
    elif 'Kumlu' in toprak and sulak > 65:
        return 'F'
    elif 'Kumlu' in toprak and 25 <= sulak < 65:
        return 'D'
    elif 'Kumlu' in toprak and sulak < 25:
        return 'E'
    else:
        return 'Z'

df['product_category'] = df.apply(determine_category, axis=1)
df[df['ilce_adi'] == 'Karapınar']
# Out:
#       ilce_adi  mahalle_adi tarimsal_sulama_suyu  \
# 511  Karapınar      HOTAMIŞ                  VAR
# 512  Karapınar       KESMEZ                  VAR
# 513  Karapınar     AKÇAYAZI                  VAR
# 514  Karapınar       AKÖREN                  VAR
# 515  Karapınar        ÇİĞİL                  VAR
# 516  Karapınar     HASANOBA                  VAR
# 517  Karapınar        İSLİK                  VAR
# 518  Karapınar    KARAKIŞLA                  VAR
# 519  Karapınar      KAYACIK                  VAR
# 520  Karapınar       KAYALI                  VAR
# 521  Karapınar  KAZANHÜYÜĞÜ                  VAR
# 522  Karapınar  KÜÇÜKAŞLAMA                  VAR
# 523  Karapınar      ORTAOBA                  VAR
# 524  Karapınar       OYMALI                  VAR
# 525  Karapınar   SAZLIPINAR                  VAR
# 526  Karapınar   YAĞMAPINAR                  VAR
# 527  Karapınar     YENİKUYU                  VAR
# 528  Karapınar    YEŞİLYURT                  VAR
#
# ...

# %%
#df.to_excel('../data/model_data_rain_karapinar_update.xlsx', index=False)
